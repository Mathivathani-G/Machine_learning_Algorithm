# %%
import cv2
import math
from ultralytics import YOLO
from IPython.display import display
import ipywidgets as widgets

# Load the YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Pre-defined list of correct predictions (for demonstration purposes)
# In real-world usage, this list would be dynamically provided
correct_predictions = ["cell phone"]  # Example list

# Function to process and display the video frames
def capture_and_detect():
    # Start the built-in camera
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    # Widget to display the live video feed
    image_widget = widgets.Image(format='jpeg')
    display(image_widget)
    cellphone_count = 0

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture image")
                break

            results = model(frame, stream=True)

            for r in results:
                boxes = r.boxes
                for box in boxes:
                    # Bounding box
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                    # Draw bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

                    # Confidence
                    confidence = math.ceil((box.conf[0] * 100)) / 100

                    # Class name
                    cls = int(box.cls[0])
                    class_name = classNames[cls]
                    # Check if the predicted class is correct
                    classification = 1 if class_name in correct_predictions else 0
                    if class_name == "cell phone":
                        cellphone_count += 1

                    # Print the result in the console
                    print(f"Class name: {class_name}, Confidence: {confidence}, Classification: {classification}")

                    # Object details
                    org = (x1, y1 - 10)
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    fontScale = 0.5
                    color = (255, 0, 0)
                    thickness = 2

                    cv2.putText(frame, f"{class_name} {confidence}", org, font, fontScale, color, thickness)

            # Encode the frame in JPEG format
            _, jpeg = cv2.imencode('.jpeg', frame)
            image_widget.value = jpeg.tobytes()
            print(f"Total 'cell phone' predictions: {cellphone_count}")

            # Update the display
            #display(image_widget)

            # Exit on 'q' key press
            if cv2.waitKey(1) & 0xFF == ord('q'):
                  break
    finally:
        cap.release()
        cv2.destroyAllWindows()

# Call the function to start the live detection
capture_and_detect()
# Out:
# Image(value=b'', format='jpeg')
# 0: 384x640 1 tv, 87.4ms
# Class name: tvmonitor, Confidence: 0.45, Classification: 0
# Speed: 2.2ms preprocess, 87.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 98.5ms
# Class name: person, Confidence: 0.74, Classification: 0
# Speed: 2.2ms preprocess, 98.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 airplane, 101.3ms
# Class name: aeroplane, Confidence: 0.27, Classification: 0
# Speed: 2.4ms preprocess, 101.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 98.3ms
# Speed: 3.2ms preprocess, 98.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 133.6ms
# Class name: person, Confidence: 0.27, Classification: 0
# Speed: 11.5ms preprocess, 133.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 112.1ms
# Speed: 2.7ms preprocess, 112.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 100.8ms
# Speed: 2.3ms preprocess, 100.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 96.9ms
# Speed: 4.3ms preprocess, 96.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 93.4ms
# Class name: book, Confidence: 0.69, Classification: 0
# Class name: person, Confidence: 0.41, Classification: 0
# Speed: 2.7ms preprocess, 93.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 87.0ms
# Class name: book, Confidence: 0.63, Classification: 0
# Class name: person, Confidence: 0.39, Classification: 0
# Speed: 2.7ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 book, 92.9ms
# Class name: book, Confidence: 0.5, Classification: 0
# Speed: 2.3ms preprocess, 92.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.6ms
# Class name: person, Confidence: 0.61, Classification: 0
# Class name: book, Confidence: 0.5, Classification: 0
# Speed: 3.1ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 126.8ms
# Speed: 1.9ms preprocess, 126.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 mouse, 1 book, 89.6ms
# Class name: person, Confidence: 0.66, Classification: 0
# Class name: book, Confidence: 0.46, Classification: 0
# Class name: mouse, Confidence: 0.44, Classification: 0
# Speed: 1.9ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 87.0ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: book, Confidence: 0.62, Classification: 0
# Speed: 1.9ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 2 persons, 1 book, 88.5ms
# Class name: person, Confidence: 0.7, Classification: 0
# Class name: book, Confidence: 0.63, Classification: 0
# Class name: person, Confidence: 0.28, Classification: 0
# Speed: 2.2ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 85.5ms
# Class name: person, Confidence: 0.68, Classification: 0
# Speed: 2.1ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 91.1ms
# Class name: person, Confidence: 0.62, Classification: 0
# Speed: 2.1ms preprocess, 91.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.6ms
# Class name: person, Confidence: 0.59, Classification: 0
# Class name: book, Confidence: 0.37, Classification: 0
# Speed: 1.9ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 98.2ms
# Class name: person, Confidence: 0.73, Classification: 0
# Speed: 4.8ms preprocess, 98.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.1ms
# Class name: person, Confidence: 0.71, Classification: 0
# Class name: book, Confidence: 0.26, Classification: 0
# Speed: 2.1ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 85.5ms
# Class name: person, Confidence: 0.65, Classification: 0
# Class name: book, Confidence: 0.57, Classification: 0
# Speed: 2.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.4ms
# Class name: person, Confidence: 0.71, Classification: 0
# Class name: book, Confidence: 0.58, Classification: 0
# Speed: 2.1ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.3ms
# Class name: person, Confidence: 0.69, Classification: 0
# Class name: book, Confidence: 0.57, Classification: 0
# Speed: 1.9ms preprocess, 86.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.7ms
# Class name: person, Confidence: 0.67, Classification: 0
# Class name: book, Confidence: 0.58, Classification: 0
# Speed: 2.0ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 87.4ms
# Class name: person, Confidence: 0.66, Classification: 0
# Class name: book, Confidence: 0.49, Classification: 0
# Speed: 2.0ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 134.8ms
# Class name: person, Confidence: 0.68, Classification: 0
# Class name: book, Confidence: 0.39, Classification: 0
# Speed: 2.0ms preprocess, 134.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 97.2ms
# Class name: person, Confidence: 0.67, Classification: 0
# Class name: book, Confidence: 0.47, Classification: 0
# Speed: 2.3ms preprocess, 97.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 90.5ms
# Class name: person, Confidence: 0.67, Classification: 0
# Class name: book, Confidence: 0.5, Classification: 0
# Speed: 2.6ms preprocess, 90.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.2ms
# Class name: person, Confidence: 0.69, Classification: 0
# Class name: book, Confidence: 0.37, Classification: 0
# Speed: 2.4ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.5ms
# Class name: person, Confidence: 0.61, Classification: 0
# Class name: book, Confidence: 0.42, Classification: 0
# Speed: 1.9ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 85.5ms
# Class name: person, Confidence: 0.66, Classification: 0
# Class name: book, Confidence: 0.55, Classification: 0
# Speed: 2.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.3ms
# Class name: person, Confidence: 0.66, Classification: 0
# Class name: book, Confidence: 0.46, Classification: 0
# Speed: 2.4ms preprocess, 86.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 121.4ms
# Class name: person, Confidence: 0.69, Classification: 0
# Class name: book, Confidence: 0.49, Classification: 0
# Speed: 2.1ms preprocess, 121.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 87.2ms
# Class name: person, Confidence: 0.7, Classification: 0
# Class name: book, Confidence: 0.49, Classification: 0
# Speed: 2.0ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 87.4ms
# Class name: person, Confidence: 0.69, Classification: 0
# Class name: book, Confidence: 0.51, Classification: 0
# Speed: 2.4ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 86.0ms
# Class name: person, Confidence: 0.68, Classification: 0
# Class name: book, Confidence: 0.49, Classification: 0
# Speed: 1.9ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 85.5ms
# Class name: person, Confidence: 0.66, Classification: 0
# Class name: book, Confidence: 0.47, Classification: 0
# Speed: 2.3ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 85.7ms
# Class name: person, Confidence: 0.69, Classification: 0
# Class name: book, Confidence: 0.5, Classification: 0
# Speed: 2.1ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 84.9ms
# Class name: person, Confidence: 0.71, Classification: 0
# Class name: book, Confidence: 0.48, Classification: 0
# Speed: 2.1ms preprocess, 84.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 120.6ms
# Class name: person, Confidence: 0.73, Classification: 0
# Class name: book, Confidence: 0.49, Classification: 0
# Speed: 1.9ms preprocess, 120.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 book, 85.2ms
# Class name: person, Confidence: 0.73, Classification: 0
# Class name: book, Confidence: 0.5, Classification: 0
# Speed: 1.9ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 97
#      94         cv2.destroyAllWindows()
#      96 # Call the function to start the live detection
# ---> 97 capture_and_detect()
#
# Cell In[2], line 48, in capture_and_detect()
#      44     break
#      46 results = model(frame, stream=True)
# ---> 48 for r in results:
#      49     boxes = r.boxes
#      50     for box in boxes:
#      51         # Bounding box
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:455, in AutoBackend.forward(self, im, augment, visualize, embed)
#     453 # PyTorch
#     454 if self.pt or self.nn_module:
# --> 455     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     457 # TorchScript
#     458 elif self.jit:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:102, in BaseModel.forward(self, x, *args, **kwargs)
#     100 if isinstance(x, dict):  # for cases of training and validating while training.
#     101     return self.loss(x, *args, **kwargs)
# --> 102 return self.predict(x, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:120, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     118 if augment:
#     119     return self._predict_augment(x)
# --> 120 return self._predict_once(x, profile, visualize, embed)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:141, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     139 if profile:
#     140     self._profile_one_layer(m, x, dt)
# --> 141 x = m(x)  # run
#     142 y.append(x if m.i in self.save else None)  # save output
#     143 if visualize:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:239, in C2f.forward(self, x)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:239, in <genexpr>(.0)
#     237 """Forward pass through C2f layer."""
#     238 y = list(self.cv1(x).chunk(2, 1))
# --> 239 y.extend(m(y[-1]) for m in self.m)
#     240 return self.cv2(torch.cat(y, 1))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/modules/block.py:349, in Bottleneck.forward(self, x)
#     347 def forward(self, x):
#     348     """'forward()' applies the YOLO FPN to input data."""
# --> 349     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
