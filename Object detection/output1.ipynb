# %%
import cv2
import math
from ultralytics import YOLO
from IPython.display import display
import ipywidgets as widgets

# Load the YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"]

# Pre-defined list of correct predictions (for demonstration purposes)
# In real-world usage, this list would be dynamically provided
correct_predictions = ["cell phone"]  # Example list

# Function to process and display the video frames
def capture_and_detect():
    # Start the built-in camera
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Error: Could not open camera.")
        return

    # Widget to display the live video feed
    image_widget = widgets.Image(format='jpeg')
    display(image_widget)
    cellphone_count = 0

    try:
        while True:
            ret, frame = cap.read()
            if not ret:
                print("Failed to capture image")
                break

            results = model(frame, stream=True)

            for r in results:
                boxes = r.boxes
                for box in boxes:
                    # Bounding box
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                    # Draw bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

                    # Confidence
                    confidence = math.ceil((box.conf[0] * 100)) / 100

                    # Class name
                    cls = int(box.cls[0])
                    class_name = classNames[cls]
                    # Check if the predicted class is correct
                    classification = 1 if class_name in correct_predictions else 0
                    if class_name == "cell phone":
                        cellphone_count += 1

                    # Print the result in the console
                    print(f"Class name: {class_name}, Confidence: {confidence}, Classification: {classification}")

                    # Object details
                    org = (x1, y1 - 10)
                    font = cv2.FONT_HERSHEY_SIMPLEX
                    fontScale = 0.5
                    color = (255, 0, 0)
                    thickness = 2

                    cv2.putText(frame, f"{class_name} {confidence}", org, font, fontScale, color, thickness)

            # Encode the frame in JPEG format
            _, jpeg = cv2.imencode('.jpeg', frame)
            image_widget.value = jpeg.tobytes()
            print(f"Total 'cell phone' predictions: {cellphone_count}")

            # Update the display
            #display(image_widget)

            # Exit on 'q' key press
            if cv2.waitKey(1) & 0xFF == ord('q'):
                  break
    finally:
        cap.release()
        cv2.destroyAllWindows()

# Call the function to start the live detection
capture_and_detect()
# Out:
# Image(value=b'', format='jpeg')
# 0: 384x640 (no detections), 95.6ms
# Speed: 6.0ms preprocess, 95.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 92.6ms
# Speed: 4.0ms preprocess, 92.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 91.3ms
# Speed: 3.1ms preprocess, 91.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 100.4ms
# Speed: 3.4ms preprocess, 100.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 100.1ms
# Speed: 2.9ms preprocess, 100.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 108.9ms
# Speed: 2.3ms preprocess, 108.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 105.2ms
# Speed: 2.6ms preprocess, 105.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 109.9ms
# Speed: 3.3ms preprocess, 109.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 88.4ms
# Speed: 2.4ms preprocess, 88.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 1.9ms preprocess, 86.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 kite, 86.4ms
# Class name: kite, Confidence: 0.28, Classification: 0
# Speed: 1.9ms preprocess, 86.4ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.8ms
# Speed: 2.5ms preprocess, 86.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 1.9ms preprocess, 86.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 86.4ms
# Class name: person, Confidence: 0.44, Classification: 0
# Speed: 1.9ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 88.3ms
# Speed: 2.5ms preprocess, 88.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 87.9ms
# Speed: 2.0ms preprocess, 87.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.3ms
# Speed: 1.9ms preprocess, 85.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.3ms
# Speed: 1.9ms preprocess, 85.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 90.3ms
# Speed: 1.9ms preprocess, 90.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 101.9ms
# Speed: 2.2ms preprocess, 101.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 87.1ms
# Speed: 1.9ms preprocess, 87.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.3ms
# Speed: 2.0ms preprocess, 86.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 84.6ms
# Speed: 1.9ms preprocess, 84.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.2ms
# Speed: 2.2ms preprocess, 86.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.0ms
# Speed: 2.4ms preprocess, 86.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 101.5ms
# Speed: 1.9ms preprocess, 101.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 87.2ms
# Speed: 2.8ms preprocess, 87.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 84.9ms
# Speed: 1.9ms preprocess, 84.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.1ms
# Speed: 1.9ms preprocess, 85.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.3ms
# Speed: 2.4ms preprocess, 85.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 airplane, 85.0ms
# Class name: aeroplane, Confidence: 0.26, Classification: 0
# Speed: 2.1ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.5ms
# Speed: 1.9ms preprocess, 85.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 2.0ms preprocess, 85.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.8ms
# Speed: 1.9ms preprocess, 85.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.9ms
# Speed: 2.1ms preprocess, 85.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.2ms
# Speed: 2.1ms preprocess, 85.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.0ms
# Speed: 2.2ms preprocess, 85.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 85.6ms
# Speed: 2.0ms preprocess, 85.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 (no detections), 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 84.5ms
# Class name: person, Confidence: 0.38, Classification: 0
# Speed: 2.0ms preprocess, 84.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 85.1ms
# Class name: person, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 0
#
# 0: 384x640 1 person, 1 cell phone, 85.4ms
# Class name: person, Confidence: 0.7, Classification: 0
# Class name: cell phone, Confidence: 0.63, Classification: 1
# Speed: 2.1ms preprocess, 85.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 1
#
# 0: 384x640 1 person, 1 cell phone, 85.5ms
# Class name: cell phone, Confidence: 0.83, Classification: 1
# Class name: person, Confidence: 0.76, Classification: 0
# Speed: 2.2ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 2
#
# 0: 384x640 1 person, 1 cell phone, 84.8ms
# Class name: cell phone, Confidence: 0.91, Classification: 1
# Class name: person, Confidence: 0.68, Classification: 0
# Speed: 1.9ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 3
#
# 0: 384x640 1 person, 1 cell phone, 85.0ms
# Class name: cell phone, Confidence: 0.92, Classification: 1
# Class name: person, Confidence: 0.75, Classification: 0
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 4
#
# 0: 384x640 1 person, 1 cell phone, 85.8ms
# Class name: cell phone, Confidence: 0.93, Classification: 1
# Class name: person, Confidence: 0.72, Classification: 0
# Speed: 2.1ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 5
#
# 0: 384x640 1 person, 1 cell phone, 98.6ms
# Class name: cell phone, Confidence: 0.94, Classification: 1
# Class name: person, Confidence: 0.7, Classification: 0
# Speed: 1.9ms preprocess, 98.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 6
#
# 0: 384x640 1 person, 1 cell phone, 85.2ms
# Class name: cell phone, Confidence: 0.93, Classification: 1
# Class name: person, Confidence: 0.72, Classification: 0
# Speed: 1.9ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 7
#
# 0: 384x640 1 person, 1 cell phone, 86.0ms
# Class name: cell phone, Confidence: 0.93, Classification: 1
# Class name: person, Confidence: 0.78, Classification: 0
# Speed: 2.0ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 8
#
# 0: 384x640 2 persons, 1 cell phone, 85.0ms
# Class name: cell phone, Confidence: 0.94, Classification: 1
# Class name: person, Confidence: 0.61, Classification: 0
# Class name: person, Confidence: 0.51, Classification: 0
# Speed: 2.1ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 9
#
# 0: 384x640 2 persons, 1 cell phone, 84.9ms
# Class name: cell phone, Confidence: 0.96, Classification: 1
# Class name: person, Confidence: 0.58, Classification: 0
# Class name: person, Confidence: 0.54, Classification: 0
# Speed: 1.9ms preprocess, 84.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 10
#
# 0: 384x640 2 persons, 1 cell phone, 85.1ms
# Class name: cell phone, Confidence: 0.96, Classification: 1
# Class name: person, Confidence: 0.72, Classification: 0
# Class name: person, Confidence: 0.35, Classification: 0
# Speed: 1.9ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 11
#
# 0: 384x640 2 persons, 1 cell phone, 85.5ms
# Class name: cell phone, Confidence: 0.88, Classification: 1
# Class name: person, Confidence: 0.77, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.1ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 12
#
# 0: 384x640 1 person, 1 cell phone, 87.4ms
# Class name: cell phone, Confidence: 0.9, Classification: 1
# Class name: person, Confidence: 0.73, Classification: 0
# Speed: 1.9ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 13
#
# 0: 384x640 1 person, 1 cell phone, 102.9ms
# Class name: cell phone, Confidence: 0.9, Classification: 1
# Class name: person, Confidence: 0.82, Classification: 0
# Speed: 2.0ms preprocess, 102.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 14
#
# 0: 384x640 1 person, 1 cell phone, 85.0ms
# Class name: cell phone, Confidence: 0.92, Classification: 1
# Class name: person, Confidence: 0.82, Classification: 0
# Speed: 1.9ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 15
#
# 0: 384x640 2 persons, 1 cell phone, 85.4ms
# Class name: cell phone, Confidence: 0.91, Classification: 1
# Class name: person, Confidence: 0.8, Classification: 0
# Class name: person, Confidence: 0.32, Classification: 0
# Speed: 2.1ms preprocess, 85.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 16
#
# 0: 384x640 2 persons, 1 cell phone, 85.5ms
# Class name: cell phone, Confidence: 0.92, Classification: 1
# Class name: person, Confidence: 0.78, Classification: 0
# Class name: person, Confidence: 0.36, Classification: 0
# Speed: 2.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 17
#
# 0: 384x640 1 person, 1 cell phone, 84.6ms
# Class name: cell phone, Confidence: 0.94, Classification: 1
# Class name: person, Confidence: 0.82, Classification: 0
# Speed: 1.9ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 18
#
# 0: 384x640 2 persons, 1 cell phone, 85.0ms
# Class name: cell phone, Confidence: 0.95, Classification: 1
# Class name: person, Confidence: 0.76, Classification: 0
# Class name: person, Confidence: 0.26, Classification: 0
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 19
#
# 0: 384x640 2 persons, 1 cell phone, 85.8ms
# Class name: cell phone, Confidence: 0.97, Classification: 1
# Class name: person, Confidence: 0.62, Classification: 0
# Class name: person, Confidence: 0.47, Classification: 0
# Speed: 1.9ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 20
#
# 0: 384x640 2 persons, 1 cell phone, 84.9ms
# Class name: cell phone, Confidence: 0.96, Classification: 1
# Class name: person, Confidence: 0.61, Classification: 0
# Class name: person, Confidence: 0.42, Classification: 0
# Speed: 2.0ms preprocess, 84.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 21
#
# 0: 384x640 1 cell phone, 98.9ms
# Class name: cell phone, Confidence: 0.75, Classification: 1
# Speed: 1.9ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 84.6ms
# Class name: person, Confidence: 0.52, Classification: 0
# Speed: 2.1ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 85.1ms
# Class name: person, Confidence: 0.64, Classification: 0
# Speed: 1.9ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 84.5ms
# Class name: person, Confidence: 0.79, Classification: 0
# Speed: 1.9ms preprocess, 84.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 85.1ms
# Class name: person, Confidence: 0.64, Classification: 0
# Speed: 2.0ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 84.7ms
# Class name: person, Confidence: 0.61, Classification: 0
# Speed: 1.9ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 84.7ms
# Class name: person, Confidence: 0.68, Classification: 0
# Speed: 2.0ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 85.5ms
# Class name: person, Confidence: 0.64, Classification: 0
# Speed: 1.9ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 couch, 98.8ms
# Class name: person, Confidence: 0.52, Classification: 0
# Class name: sofa, Confidence: 0.47, Classification: 0
# Speed: 2.0ms preprocess, 98.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 85.8ms
# Class name: person, Confidence: 0.53, Classification: 0
# Speed: 1.9ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 84.6ms
# Class name: person, Confidence: 0.42, Classification: 0
# Class name: bed, Confidence: 0.3, Classification: 0
# Speed: 1.9ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 84.8ms
# Class name: person, Confidence: 0.55, Classification: 0
# Speed: 2.0ms preprocess, 84.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 85.0ms
# Class name: person, Confidence: 0.45, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 85.2ms
# Class name: person, Confidence: 0.57, Classification: 0
# Class name: chair, Confidence: 0.49, Classification: 0
# Class name: bed, Confidence: 0.32, Classification: 0
# Speed: 1.9ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 84.7ms
# Class name: person, Confidence: 0.51, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 1.9ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 102.0ms
# Class name: person, Confidence: 0.62, Classification: 0
# Class name: bed, Confidence: 0.32, Classification: 0
# Class name: chair, Confidence: 0.29, Classification: 0
# Speed: 2.1ms preprocess, 102.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 87.3ms
# Class name: person, Confidence: 0.62, Classification: 0
# Class name: bed, Confidence: 0.46, Classification: 0
# Speed: 2.0ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 86.7ms
# Class name: person, Confidence: 0.58, Classification: 0
# Class name: bed, Confidence: 0.31, Classification: 0
# Class name: chair, Confidence: 0.29, Classification: 0
# Speed: 1.9ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 88.2ms
# Class name: person, Confidence: 0.53, Classification: 0
# Class name: chair, Confidence: 0.37, Classification: 0
# Class name: bed, Confidence: 0.33, Classification: 0
# Speed: 2.0ms preprocess, 88.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 85.6ms
# Class name: person, Confidence: 0.58, Classification: 0
# Class name: bed, Confidence: 0.37, Classification: 0
# Class name: chair, Confidence: 0.34, Classification: 0
# Speed: 1.9ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 87.8ms
# Class name: person, Confidence: 0.62, Classification: 0
# Class name: bed, Confidence: 0.46, Classification: 0
# Class name: chair, Confidence: 0.3, Classification: 0
# Speed: 2.0ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 86.1ms
# Class name: person, Confidence: 0.52, Classification: 0
# Class name: chair, Confidence: 0.35, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Speed: 1.9ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 99.1ms
# Class name: person, Confidence: 0.59, Classification: 0
# Class name: bed, Confidence: 0.3, Classification: 0
# Speed: 2.0ms preprocess, 99.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 86.2ms
# Class name: person, Confidence: 0.58, Classification: 0
# Class name: chair, Confidence: 0.33, Classification: 0
# Class name: bed, Confidence: 0.32, Classification: 0
# Speed: 1.9ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 86.5ms
# Class name: person, Confidence: 0.55, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Class name: chair, Confidence: 0.28, Classification: 0
# Speed: 2.0ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 88.8ms
# Class name: person, Confidence: 0.62, Classification: 0
# Class name: bed, Confidence: 0.44, Classification: 0
# Speed: 2.0ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 87.0ms
# Class name: person, Confidence: 0.73, Classification: 0
# Class name: bed, Confidence: 0.36, Classification: 0
# Class name: chair, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 87.0ms
# Class name: person, Confidence: 0.65, Classification: 0
# Class name: bed, Confidence: 0.4, Classification: 0
# Speed: 2.0ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 87.0ms
# Class name: person, Confidence: 0.7, Classification: 0
# Class name: bed, Confidence: 0.45, Classification: 0
# Class name: chair, Confidence: 0.26, Classification: 0
# Speed: 2.0ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 101.4ms
# Class name: person, Confidence: 0.68, Classification: 0
# Class name: bed, Confidence: 0.45, Classification: 0
# Class name: chair, Confidence: 0.35, Classification: 0
# Speed: 2.0ms preprocess, 101.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 kite, 1 chair, 1 bed, 86.1ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: bed, Confidence: 0.43, Classification: 0
# Class name: chair, Confidence: 0.38, Classification: 0
# Class name: kite, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 85.2ms
# Class name: person, Confidence: 0.78, Classification: 0
# Class name: bed, Confidence: 0.43, Classification: 0
# Class name: chair, Confidence: 0.42, Classification: 0
# Speed: 2.0ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 86.0ms
# Class name: person, Confidence: 0.65, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 1.9ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 85.5ms
# Class name: person, Confidence: 0.8, Classification: 0
# Class name: bed, Confidence: 0.38, Classification: 0
# Class name: chair, Confidence: 0.36, Classification: 0
# Speed: 2.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 85.5ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: bed, Confidence: 0.5, Classification: 0
# Class name: chair, Confidence: 0.32, Classification: 0
# Speed: 2.1ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 85.6ms
# Class name: person, Confidence: 0.83, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Speed: 1.9ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 chair, 1 bed, 100.1ms
# Class name: person, Confidence: 0.8, Classification: 0
# Class name: bed, Confidence: 0.35, Classification: 0
# Class name: chair, Confidence: 0.34, Classification: 0
# Speed: 2.0ms preprocess, 100.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 86.2ms
# Class name: person, Confidence: 0.83, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Speed: 1.9ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 90.2ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: bed, Confidence: 0.36, Classification: 0
# Speed: 1.9ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 86.3ms
# Class name: person, Confidence: 0.79, Classification: 0
# Speed: 2.0ms preprocess, 86.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 22
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 85.6ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: cell phone, Confidence: 0.36, Classification: 1
# Class name: bed, Confidence: 0.31, Classification: 0
# Speed: 2.0ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 23
#
# 0: 384x640 1 person, 1 cell phone, 86.0ms
# Class name: person, Confidence: 0.78, Classification: 0
# Class name: cell phone, Confidence: 0.32, Classification: 1
# Speed: 2.0ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 24
#
# 0: 384x640 1 person, 85.0ms
# Class name: person, Confidence: 0.68, Classification: 0
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 24
#
# 0: 384x640 1 person, 1 bed, 100.2ms
# Class name: person, Confidence: 0.83, Classification: 0
# Class name: bed, Confidence: 0.39, Classification: 0
# Speed: 2.1ms preprocess, 100.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 24
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 86.4ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: cell phone, Confidence: 0.34, Classification: 1
# Class name: bed, Confidence: 0.28, Classification: 0
# Speed: 2.0ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 25
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 84.6ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: bed, Confidence: 0.42, Classification: 0
# Class name: cell phone, Confidence: 0.31, Classification: 1
# Speed: 1.9ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 26
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 85.7ms
# Class name: person, Confidence: 0.83, Classification: 0
# Class name: cell phone, Confidence: 0.32, Classification: 1
# Class name: bed, Confidence: 0.28, Classification: 0
# Speed: 2.0ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 27
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 85.6ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: bed, Confidence: 0.33, Classification: 0
# Class name: cell phone, Confidence: 0.28, Classification: 1
# Speed: 1.9ms preprocess, 85.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 28
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 86.1ms
# Class name: person, Confidence: 0.67, Classification: 0
# Class name: cell phone, Confidence: 0.36, Classification: 1
# Class name: bed, Confidence: 0.36, Classification: 0
# Speed: 1.9ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 29
#
# 0: 384x640 1 person, 1 bed, 85.3ms
# Class name: person, Confidence: 0.6, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 2.0ms preprocess, 85.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 29
#
# 0: 384x640 1 person, 1 bed, 107.3ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: bed, Confidence: 0.42, Classification: 0
# Speed: 1.9ms preprocess, 107.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 29
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 87.1ms
# Class name: person, Confidence: 0.68, Classification: 0
# Class name: cell phone, Confidence: 0.49, Classification: 1
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 2.0ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 30
#
# 0: 384x640 1 person, 1 cell phone, 86.4ms
# Class name: person, Confidence: 0.79, Classification: 0
# Class name: cell phone, Confidence: 0.53, Classification: 1
# Speed: 1.9ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 88.2ms
# Class name: person, Confidence: 0.88, Classification: 0
# Class name: bed, Confidence: 0.44, Classification: 0
# Class name: person, Confidence: 0.3, Classification: 0
# Speed: 1.9ms preprocess, 88.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 84.7ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: bed, Confidence: 0.4, Classification: 0
# Class name: person, Confidence: 0.33, Classification: 0
# Speed: 1.9ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 88.1ms
# Class name: person, Confidence: 0.74, Classification: 0
# Class name: bed, Confidence: 0.44, Classification: 0
# Class name: person, Confidence: 0.37, Classification: 0
# Speed: 1.9ms preprocess, 88.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 89.8ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: person, Confidence: 0.38, Classification: 0
# Class name: bed, Confidence: 0.36, Classification: 0
# Speed: 1.9ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 99.3ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: bed, Confidence: 0.45, Classification: 0
# Class name: person, Confidence: 0.42, Classification: 0
# Speed: 2.1ms preprocess, 99.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 88.9ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: person, Confidence: 0.3, Classification: 0
# Class name: bed, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 88.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 85.5ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Speed: 2.0ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.4ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: bed, Confidence: 0.4, Classification: 0
# Class name: person, Confidence: 0.31, Classification: 0
# Speed: 2.0ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.0ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: bed, Confidence: 0.45, Classification: 0
# Class name: person, Confidence: 0.28, Classification: 0
# Speed: 1.9ms preprocess, 86.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 86.1ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: bed, Confidence: 0.44, Classification: 0
# Speed: 1.9ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 85.8ms
# Class name: person, Confidence: 0.89, Classification: 0
# Class name: bed, Confidence: 0.43, Classification: 0
# Speed: 2.0ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 101.4ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: bed, Confidence: 0.46, Classification: 0
# Class name: person, Confidence: 0.28, Classification: 0
# Speed: 2.1ms preprocess, 101.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 89.9ms
# Class name: person, Confidence: 0.79, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Class name: person, Confidence: 0.32, Classification: 0
# Speed: 1.9ms preprocess, 89.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 86.6ms
# Class name: person, Confidence: 0.89, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Speed: 2.0ms preprocess, 86.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 87.9ms
# Class name: person, Confidence: 0.88, Classification: 0
# Class name: bed, Confidence: 0.37, Classification: 0
# Speed: 2.0ms preprocess, 87.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 84.7ms
# Class name: person, Confidence: 0.85, Classification: 0
# Class name: bed, Confidence: 0.39, Classification: 0
# Speed: 1.9ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.7ms
# Class name: person, Confidence: 0.85, Classification: 0
# Class name: bed, Confidence: 0.32, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.1ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.5ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: bed, Confidence: 0.4, Classification: 0
# Class name: person, Confidence: 0.31, Classification: 0
# Speed: 1.9ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 88.8ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: person, Confidence: 0.36, Classification: 0
# Class name: bed, Confidence: 0.32, Classification: 0
# Speed: 4.9ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.7ms
# Class name: person, Confidence: 0.85, Classification: 0
# Class name: bed, Confidence: 0.42, Classification: 0
# Class name: person, Confidence: 0.32, Classification: 0
# Speed: 2.0ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.1ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: bed, Confidence: 0.43, Classification: 0
# Class name: person, Confidence: 0.31, Classification: 0
# Speed: 2.0ms preprocess, 86.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.2ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: bed, Confidence: 0.46, Classification: 0
# Class name: person, Confidence: 0.34, Classification: 0
# Speed: 2.4ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 87.1ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: bed, Confidence: 0.29, Classification: 0
# Speed: 1.9ms preprocess, 87.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.9ms
# Class name: person, Confidence: 0.84, Classification: 0
# Class name: person, Confidence: 0.32, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 86.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.3ms
# Class name: person, Confidence: 0.73, Classification: 0
# Class name: bed, Confidence: 0.46, Classification: 0
# Class name: person, Confidence: 0.45, Classification: 0
# Speed: 1.9ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 107.7ms
# Class name: person, Confidence: 0.78, Classification: 0
# Class name: bed, Confidence: 0.55, Classification: 0
# Class name: person, Confidence: 0.44, Classification: 0
# Speed: 2.0ms preprocess, 107.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 86.4ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: bed, Confidence: 0.41, Classification: 0
# Class name: person, Confidence: 0.26, Classification: 0
# Speed: 1.9ms preprocess, 86.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 87.6ms
# Class name: person, Confidence: 0.9, Classification: 0
# Class name: bed, Confidence: 0.34, Classification: 0
# Speed: 2.0ms preprocess, 87.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.6ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: person, Confidence: 0.34, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 2.0ms preprocess, 87.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 88.3ms
# Class name: person, Confidence: 0.8, Classification: 0
# Class name: person, Confidence: 0.43, Classification: 0
# Speed: 1.9ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 87.3ms
# Class name: person, Confidence: 0.89, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 87.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 87.2ms
# Class name: person, Confidence: 0.9, Classification: 0
# Speed: 1.9ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 101.4ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: bed, Confidence: 0.3, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 101.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 86.5ms
# Class name: person, Confidence: 0.9, Classification: 0
# Speed: 1.9ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.8ms
# Class name: person, Confidence: 0.89, Classification: 0
# Class name: bed, Confidence: 0.29, Classification: 0
# Class name: person, Confidence: 0.26, Classification: 0
# Speed: 2.0ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 100.6ms
# Class name: person, Confidence: 0.79, Classification: 0
# Class name: person, Confidence: 0.42, Classification: 0
# Class name: bed, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 100.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 88.8ms
# Class name: person, Confidence: 0.8, Classification: 0
# Class name: person, Confidence: 0.35, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 2.0ms preprocess, 88.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 87.7ms
# Class name: person, Confidence: 0.68, Classification: 0
# Class name: person, Confidence: 0.51, Classification: 0
# Speed: 2.0ms preprocess, 87.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 89.7ms
# Class name: person, Confidence: 0.78, Classification: 0
# Class name: person, Confidence: 0.41, Classification: 0
# Speed: 2.0ms preprocess, 89.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 99.9ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: person, Confidence: 0.35, Classification: 0
# Speed: 2.1ms preprocess, 99.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 1 bed, 87.1ms
# Class name: person, Confidence: 0.86, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 2 persons, 85.0ms
# Class name: person, Confidence: 0.87, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 31
#
# 0: 384x640 1 person, 1 bed, 1 cell phone, 85.7ms
# Class name: person, Confidence: 0.81, Classification: 0
# Class name: cell phone, Confidence: 0.56, Classification: 1
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 2.1ms preprocess, 85.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 32
#
# 0: 384x640 1 person, 1 cell phone, 86.5ms
# Class name: cell phone, Confidence: 0.83, Classification: 1
# Class name: person, Confidence: 0.78, Classification: 0
# Speed: 2.0ms preprocess, 86.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 33
#
# 0: 384x640 1 person, 1 cell phone, 85.1ms
# Class name: person, Confidence: 0.82, Classification: 0
# Class name: cell phone, Confidence: 0.76, Classification: 1
# Speed: 2.0ms preprocess, 85.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 4 persons, 85.2ms
# Class name: person, Confidence: 0.63, Classification: 0
# Class name: person, Confidence: 0.56, Classification: 0
# Class name: person, Confidence: 0.41, Classification: 0
# Class name: person, Confidence: 0.29, Classification: 0
# Speed: 2.1ms preprocess, 85.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 100.2ms
# Class name: person, Confidence: 0.61, Classification: 0
# Speed: 2.0ms preprocess, 100.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 85.5ms
# Class name: person, Confidence: 0.74, Classification: 0
# Speed: 1.9ms preprocess, 85.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 2 persons, 85.0ms
# Class name: person, Confidence: 0.73, Classification: 0
# Class name: person, Confidence: 0.69, Classification: 0
# Speed: 2.1ms preprocess, 85.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 2 persons, 103.8ms
# Class name: person, Confidence: 0.67, Classification: 0
# Class name: person, Confidence: 0.39, Classification: 0
# Speed: 2.3ms preprocess, 103.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 88.5ms
# Class name: person, Confidence: 0.8, Classification: 0
# Speed: 2.6ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 2 persons, 96.4ms
# Class name: person, Confidence: 0.75, Classification: 0
# Class name: person, Confidence: 0.39, Classification: 0
# Speed: 2.0ms preprocess, 96.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 85.8ms
# Class name: person, Confidence: 0.81, Classification: 0
# Speed: 2.2ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 2 persons, 100.5ms
# Class name: person, Confidence: 0.54, Classification: 0
# Class name: person, Confidence: 0.46, Classification: 0
# Speed: 2.2ms preprocess, 100.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 85.9ms
# Class name: person, Confidence: 0.81, Classification: 0
# Speed: 2.0ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 87.5ms
# Class name: person, Confidence: 0.89, Classification: 0
# Speed: 1.9ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 87.5ms
# Class name: person, Confidence: 0.9, Classification: 0
# Speed: 2.3ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 34
#
# 0: 384x640 1 person, 89.9ms
# Class name: person, Confidence: 0.8, Classification: 0
# ...
# Speed: 3.2ms preprocess, 88.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 92.3ms
# Class name: bed, Confidence: 0.56, Classification: 0
# Speed: 1.9ms preprocess, 92.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 87.5ms
# Class name: bed, Confidence: 0.56, Classification: 0
# Speed: 1.9ms preprocess, 87.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 102.8ms
# Class name: bed, Confidence: 0.53, Classification: 0
# Speed: 1.9ms preprocess, 102.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 89.5ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Speed: 1.9ms preprocess, 89.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 90.0ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Speed: 1.9ms preprocess, 90.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 98.9ms
# Class name: bed, Confidence: 0.58, Classification: 0
# Speed: 1.9ms preprocess, 98.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 102.0ms
# Class name: bed, Confidence: 0.6, Classification: 0
# Speed: 2.8ms preprocess, 102.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 90.5ms
# Class name: bed, Confidence: 0.57, Classification: 0
# Speed: 1.9ms preprocess, 90.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 108.1ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Class name: bed, Confidence: 0.26, Classification: 0
# Speed: 1.9ms preprocess, 108.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 93.8ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Speed: 2.0ms preprocess, 93.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 86.7ms
# Class name: bed, Confidence: 0.57, Classification: 0
# Speed: 1.9ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 98.1ms
# Class name: bed, Confidence: 0.47, Classification: 0
# Speed: 1.9ms preprocess, 98.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 89.5ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Speed: 1.9ms preprocess, 89.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 103.5ms
# Class name: bed, Confidence: 0.5, Classification: 0
# Class name: bed, Confidence: 0.29, Classification: 0
# Speed: 2.0ms preprocess, 103.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 96.5ms
# Class name: bed, Confidence: 0.64, Classification: 0
# Speed: 2.0ms preprocess, 96.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 85.9ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Speed: 1.9ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 111.6ms
# Class name: bed, Confidence: 0.48, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 111.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 87.4ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Class name: bed, Confidence: 0.28, Classification: 0
# Speed: 1.9ms preprocess, 87.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 89.6ms
# Class name: bed, Confidence: 0.56, Classification: 0
# Class name: bed, Confidence: 0.3, Classification: 0
# Speed: 1.9ms preprocess, 89.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 86.7ms
# Class name: bed, Confidence: 0.56, Classification: 0
# Speed: 1.9ms preprocess, 86.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 1 keyboard, 91.7ms
# Class name: bed, Confidence: 0.58, Classification: 0
# Class name: keyboard, Confidence: 0.32, Classification: 0
# Speed: 1.9ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 1 keyboard, 88.5ms
# Class name: bed, Confidence: 0.54, Classification: 0
# Class name: keyboard, Confidence: 0.49, Classification: 0
# Speed: 2.0ms preprocess, 88.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 101.6ms
# Class name: bed, Confidence: 0.47, Classification: 0
# Speed: 2.0ms preprocess, 101.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 87.0ms
# Class name: bed, Confidence: 0.48, Classification: 0
# Class name: bed, Confidence: 0.26, Classification: 0
# Speed: 1.9ms preprocess, 87.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 87.2ms
# Class name: bed, Confidence: 0.51, Classification: 0
# Speed: 1.9ms preprocess, 87.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 112.7ms
# Class name: bed, Confidence: 0.54, Classification: 0
# Speed: 2.0ms preprocess, 112.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 2 beds, 91.5ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Class name: bed, Confidence: 0.27, Classification: 0
# Speed: 1.9ms preprocess, 91.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 88.1ms
# Class name: bed, Confidence: 0.55, Classification: 0
# Speed: 1.9ms preprocess, 88.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 87.8ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Speed: 1.9ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 90.2ms
# Class name: bed, Confidence: 0.52, Classification: 0
# Speed: 2.3ms preprocess, 90.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 88.3ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Speed: 2.0ms preprocess, 88.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 104.0ms
# Class name: bed, Confidence: 0.49, Classification: 0
# Speed: 1.9ms preprocess, 104.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
#
# 0: 384x640 1 bed, 100.5ms
# Class name: bed, Confidence: 0.51, Classification: 0
# Speed: 2.2ms preprocess, 100.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Total 'cell phone' predictions: 66
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 97
#      94         cv2.destroyAllWindows()
#      96 # Call the function to start the live detection
# ---> 97 capture_and_detect()
#
# Cell In[2], line 48, in capture_and_detect()
#      44     break
#      46 results = model(frame, stream=True)
# ---> 48 for r in results:
#      49     boxes = r.boxes
#      50     for box in boxes:
#      51         # Bounding box
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/autobackend.py:455, in AutoBackend.forward(self, im, augment, visualize, embed)
#     453 # PyTorch
#     454 if self.pt or self.nn_module:
# --> 455     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     457 # TorchScript
#     458 elif self.jit:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:102, in BaseModel.forward(self, x, *args, **kwargs)
#     100 if isinstance(x, dict):  # for cases of training and validating while training.
#     101     return self.loss(x, *args, **kwargs)
# --> 102 return self.predict(x, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:120, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     118 if augment:
#     119     return self._predict_augment(x)
# --> 120 return self._predict_once(x, profile, visualize, embed)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/tasks.py:141, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     139 if profile:
#     140     self._profile_one_layer(m, x, dt)
# --> 141 x = m(x)  # run
#     142 y.append(x if m.i in self.save else None)  # save output
#     143 if visualize:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/nn/modules/conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
